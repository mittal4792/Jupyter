% %%
x = magic(25)
% Out:
% x =
%
%    327   354   381   408   435   462   489   516   543   570   597   624     1    28    55    82   109   136   163   190   217   244   271   298   325
%    353   380   407   434   461   488   515   542   569   596   623    25    27    54    81   108   135   162   189   216   243   270   297   324   326
%    379   406   433   460   487   514   541   568   595   622    24    26    53    80   107   134   161   188   215   242   269   296   323   350   352
%    405   432   459   486   513   540   567   594   621    23    50    52    79   106   133   160   187   214   241   268   295   322   349   351   378
%    431   458   485   512   539   566   593   620    22    49    51    78   105   132   159   186   213   240   267   294   321   348   375   377   404
%    457   484   511   538   565   592   619    21    48    75    77   104   131   158   185   212   239   266   293   320   347   374   376   403   430
% ...

% %%
e = eig(rand(10))
% Out:
% e =
%
%    4.5561 + 0.0000i
%    0.6977 + 0.4054i
%    0.6977 - 0.4054i
%   -0.5916 + 0.0000i
%   -0.2515 + 0.0930i
%   -0.2515 - 0.0930i
%    0.1563 + 0.3522i
%    0.1563 - 0.3522i
%    0.0187 + 0.2538i
%    0.0187 - 0.2538i

% %%
plot(magic(5))

% %%
area(magic(8))

% %%
x = 12
r = rand(x)
plot(r)
title('Some random stuff')
% Out:
% x =
%
%     12
%
%
% r =
%
%     0.0963    0.4865    0.7384    0.1807    0.6780    0.7188    0.2982    0.0484    0.6417    0.1668    0.4839    0.8345
%     0.5344    0.1984    0.9388    0.5136    0.4255    0.3514    0.7444    0.1405    0.3920    0.4701    0.8732    0.4511
%     0.7568    0.1437    0.4970    0.2870    0.5281    0.0144    0.4872    0.4127    0.5539    0.0789    0.9628    0.3635
%     0.9844    0.0820    0.6205    0.7827    0.8811    0.4092    0.8545    0.4724    0.8736    0.4771    0.3231    0.9027
%     0.9236    0.8985    0.0379    0.6292    0.3076    0.1050    0.2145    0.8789    0.9131    0.6856    0.0888    0.8336
%     0.6811    0.9895    0.0341    0.3554    0.8308    0.6433    0.9694    0.7133    0.1374    0.0647    0.5403    0.7377
%     0.5854    0.1639    0.8882    0.4908    0.5958    0.8703    0.9752    0.3194    0.9475    0.0623    0.1689    0.7367
% ...

% %%
x = rand(1,6)
fprintf('The variable x has length %d\n',length(x))
% Out:
% x =
%
%     0.9300    0.8090    0.1558    0.6368    0.4220    0.6784
%
% The variable x has length 6
